# %% [markdown]
# <a href="https://colab.research.google.com/github/HannanehSepehri/persian-ner-peft/blob/main/notebooks/01_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Persian NER with Parameter-Efficient Fine-Tuning
#
# ## Environment Setup
#
# This notebook checks the software and hardware environment required for the project.
#
# ### Project methods
# - Full fine-tuning
# - LoRA
# - Adapters
#
# ### Base model
# - XLM-RoBERTa-base
#
# ### Task
# - Persian Named Entity Recognition

# %%
print("Persian NER with PEFT")
print("Project environment is ready.")
# Out:
# Persian NER with PEFT
# Project environment is ready.

# %%
import torch
print("PyTorch version :", torch.__version__)
print("GPU available :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU name :", torch.cuda.get_device_name(0))
else:
    print("GPU is not active.")
# Out:
# PyTorch version : 2.11.0+cu128
# GPU available : True
# GPU name : Tesla T4

# %%
# !pip install -q -U transformers datasets evaluate seqeval accelerate peft
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 86.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 18.2 MB/s eta 0:00:00
# ...

# %%
from importlib.metadata import version, PackageNotFoundError

packages = [
    "torch",
    "transformers",
    "datasets",
    "evaluate",
    "seqeval",
    "accelerate",
    "peft"
]

for package in packages:
    try:
        print(f"{package} version: {version(package)}")
    except PackageNotFoundError:
        print(f"{package} is not installed.")
# Out:
# torch version: 2.11.0+cu128
# transformers version: 5.13.0
# datasets version: 5.0.0
# evaluate version: 0.4.6
# seqeval version: 1.2.2
# accelerate version: 1.14.0
# peft version: 0.19.1

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print(
        "GPU memory:",
        round(torch.cuda.get_device_properties(0).total_memory / 1024**3, 2),
        "GB",
    )
else:
    print("GPU is not active.")
# Out:
# PyTorch version: 2.11.0+cu128
# CUDA available: True
# GPU name: Tesla T4
# GPU memory: 14.56 GB
